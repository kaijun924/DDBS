# %%
import json
from pymongo import MongoClient, errors
from datetime import datetime

# %%
import time
from datetime import datetime
from functools import wraps

def log_execution_time(func):
    """A decorator to log the execution time of a function."""
    @wraps(func)
    def wrapper(*args, **kwargs):
        start_time = datetime.now()
        result = func(*args, **kwargs)
        end_time = datetime.now()
        print(f"Execution time: {end_time - start_time}")
        return result
    return wrapper

def handle_exceptions(func):
    """A decorator to handle exceptions."""
    @wraps(func)
    def wrapper(*args, **kwargs):
        try:
            return func(*args, **kwargs)
        except FileNotFoundError as e:
            print(f"Error: File not found - {e}")
        except Exception as e:
            print(f"Error occurred in '{func.__name__}': {e}")
    return wrapper

# %%
class MongoDBHandler:
    """Handles MongoDB operations."""

    def __init__(self, host: str, port: int):
        """Initialize the MongoDB connection."""
        try:
            self.client = MongoClient(host, port)
            print(f"Connected to MongoDB at {host}:{port}")
            
            self.user_collection = self.client["userDatabase"]["User"]
            self.article_collection = self.client["articleDatabase"]["Article"]
            self.read_collection = self.client["readDatabase"]["Read"]
            self.be_read_collection = self.client["beReadDatabase"]["BeRead"]
            self.popular_rank_collection = self.client["popularRankDatabase"]["PopularRank"]
            
        except errors.ConnectionFailure as e:
            print(f"Error connecting to MongoDB: {e}")
            raise

    def get_database(self, db_name: str):
        """Retrieve a database."""
        return self.client[db_name]

# %%
class TableHandler:
    """Base class for handling common database operations."""    
    def __init__(self, collection):
        """Initialize with a MongoDB collection."""
        self.collection = collection
    
    @handle_exceptions
    @log_execution_time
    def bulk_insert(self, json_file: str, batch_size: int = 5000):
        """
        Bulk inserts data from a JSON file into the MongoDB collection.
        Uses the duplication_logic method for optional record transformation.
        """
        with open(json_file, 'r', encoding='utf-8') as file:
            buffer = []
            count = 0
            for line in file:
                record = json.loads(line)
                # Apply duplication logic (can be overridden in subclasses)
                records = self._process_record(record)
                buffer.extend(records)
                count += 1
                # Bulk write when buffer reaches batch_size
                if len(buffer) >= batch_size:
                    self._write_to_db(buffer)
                    buffer = []
            # Final flush of any remaining records
            if buffer:
                self._write_to_db(buffer)
        print(f"Finished processing {count} records.")

    def _process_record(self, record):
        """
        Default process record logic: No special handling.
        Override this method in subclasses for custom logic.
        """
        return [record]
    
    def _write_to_db(self, data):
        """Write data to the specified collection."""
        try:
            result = self.collection.insert_many(data, ordered=False)
            print(f"Inserted {len(result.inserted_ids)} records into {self.collection.name}")
        except errors.BulkWriteError as e:
            print(f"Error during bulk insert: {e.details}")

# %%
cache = {}

class UserTableHandler(TableHandler):
    def __init__(self, db_handler: MongoDBHandler):
        super().__init__(db_handler.user_collection)
        
    def get_region_by_uid(self, uid):
        if uid in cache:
            return cache[uid]
        else:
            user = self.collection.find_one({"uid": uid})
            cache[uid] = user.get("region") if user else None
        return cache[uid]
    
    def fetch_users(self, conditions={}, count=100, offset=0):
        if count == None:
            users = self.collection.find(conditions, { "_id": 0, "timestamp": 0, "id": 0 })
        else:
            users = self.collection.find(conditions, { "_id": 0, "timestamp": 0, "id": 0 }).skip(offset).limit(count)
        return list(users)
    
    def fetch_users_by_region(self, region: str, count=100, offset=0):
        return self.fetch_users({"region": region}, count, offset)
        
class ArticleTableHandler(TableHandler):
    def __init__(self, db_handler: MongoDBHandler):
        super().__init__(db_handler.article_collection)

    def _process_record(self, record):
        if record.get("category") == "science":
            r1 = record.copy()
            r2 = record.copy()
            r1["shardCopy"] = 1
            r2["shardCopy"] = 2
            return [r1, r2]
        return [record]
    
    def fetch_articles(self, conditions={}, count=100, offset=0):
        pipeline = [
            {
                "$match": conditions
            },
            {
                "$group": {
                    "_id": "$aid",  # Group by the unique identifier
                    "deduplicatedDoc": { "$first": "$$ROOT" }
                }
            },
            {
                "$replaceRoot": { "newRoot": "$deduplicatedDoc" }
            }
        ]
        if count != None:
            pipeline.append({"$skip": offset})
            pipeline.append({"$limit": count})

        articles = self.collection.aggregate(pipeline)
        return list(articles)
    
    def fetch_articles_by_category(self, category: str, count=100, offset=0):
        return self.fetch_articles({"category": category}, count, offset)
    
class ReadTableHandler(TableHandler):
    def __init__(self, db_handler: MongoDBHandler):
        super().__init__(db_handler.read_collection)
        self.userTableHandler = UserTableHandler(db_handler)
        
    def _process_record(self, record):
        region = self.userTableHandler.get_region_by_uid(record['uid'])
        record['region'] = region
        return [record]

    def fetch_reads(self, conditions={}, count=100, offset=0):
        ### time check, when feaching beijing user's reads. 
        ### implementation: read with added region field, which is the shard key
        fields = {
                    "_id": 0,
                    "timestamp": 0,
                    "uid": 0,
                    "region": 0
                }
        if count == None:
            reads = self.collection.find(conditions, fields)
        else:
            reads = self.collection.find(conditions, fields).skip(offset).limit(count)
        return list(reads)
    
    def fetch_reads_by_user(self, uid: int):
        return self.fetch_reads({"uid": uid}, None, None)
    
    
    def fetch_aggregated_reads_by_category(self, category: str):
        limit = 10
        """
        Aggregate reads for a specific article category.
        """
        pipeline = [
            {
                "$lookup": {
                    "from": "articleDatabase.Article",
                    "localField": "aid",
                    "foreignField": "aid",
                    "as": "article_details",
                }
            },
            {"$unwind": "$article_details"},  # Flatten the article details array
            {"$match": {"article_details.category": category}},  # Filter condition
            {"$group": {"_id": "$uid", "total_reads": {"$sum": 1}}},  # Group by user
            {"$limit": limit},
        ]
        return list(self.collection.aggregate(pipeline))
    
    def fetch_reads_with_details(self):
        limit = 10
        """
        Fetch reads with user and article details.
        Simulates a join between Reads, User, and Article collections.
        """
        pipeline = [
            {
                "$lookup": {
                    "from": "articleDatabase.Article",
                    "localField": "aid",
                    "foreignField": "aid",
                    "as": "article_details",
                }
            },
            {
                "$lookup": {
                    "from": "userDatabase.User",
                    "localField": "uid",
                    "foreignField": "uid",
                    "as": "user_details",
                }
            },
            {"$limit": limit},
        ]
        return list(self.collection.aggregate(pipeline))
    
    
        
class BeReadTableHandler(TableHandler):
    def __init__(self, db_handler: MongoDBHandler):
        super().__init__(db_handler.be_read_collection)
        self.userTableHandler = UserTableHandler(db_handler)
        
        
class PopularRankTableHandler(TableHandler):
    def __init__(self, db_handler: MongoDBHandler):
        super().__init__(db_handler.popular_rank_collection)
        
        
class QueryHandeler():
    def __init__(self, db_handler: MongoDBHandler):
        self.userTableHandler = UserTableHandler(db_handler)
        self.articleTableHandler = ArticleTableHandler(db_handler)
        self.readTableHandler = ReadTableHandler(db_handler)
        self.beReadTableHandler = BeReadTableHandler(db_handler)
        self.popularRankTableHandler = PopularRankTableHandler(db_handler)
        
    def fetch_users(self, conditions={}, count=100, offset=0):
        return self.userTableHandler.fetch_users(conditions, count, offset)
    
    def fetch_users_by_region(self, region: str, count=100, offset=0):
        return self.userTableHandler.fetch_users_by_region(region, count, offset)
    
    def fetch_articles(self, conditions={}, count=100, offset=0):
        return self.articleTableHandler.fetch_articles(conditions, count, offset)
    
    def fetch_articles_by_category(self, category: str, count=100, offset=0):
        return self.articleTableHandler.fetch_articles_by_category(category, count, offset)
    
    def fetch_reads(self, conditions={}, count=100, offset=0):
        return self.readTableHandler.fetch_reads(conditions, count, offset)
    
    def fetch_user_read(self, uid: str):
        user = self.userTableHandler.fetch_users({"uid": uid})
        reads = self.readTableHandler.fetch_reads_by_user(uid)   
        return {
            "user": user,
            "reads": reads
        }
        
        
    # 3) Populate the empty Be-Read table by inserting newly computed records into the
    # Be-Read table.
    # 4) Query the top-5 daily/weekly/monthly popular articles with articles details (text,
    # image, and video if existing) (involving the join of Be-Read table and Article
    # table)

# %%
# Configuration
host = "localhost"
port = 60000
db_handler = MongoDBHandler(host, port)
# Out:
# Connected to MongoDB at localhost:60000

# %%
q = QueryHandeler(db_handler)
q.fetch_user_read("1")
# Out:
# {'user': [{'uid': '1',
#    'name': 'user1',
#    'gender': 'male',
#    'email': 'email1',
#    'phone': 'phone1',
#    'dept': 'dept0',
#    'grade': 'grade2',
#    'language': 'zh',
#    'region': 'Beijing',
#    'role': 'role0',
#    'preferTags': 'tags36',
#    'obtainedCredits': '55'},
#   {'uid': '1',
#    'name': 'user1',
#    'gender': 'male',
#    'email': 'email1',
#    'phone': 'phone1',
#    'dept': 'dept0',
#    'grade': 'grade2',
#    'language': 'zh',
#    'region': 'Beijing',
#    'role': 'role0',
#    'preferTags': 'tags36',
#    'obtainedCredits': '55'}],
#  'reads': [{'id': 'r13790',
#    'aid': '3643',
#    'readTimeLength': '24',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,3643)'},
#   {'id': 'r17715',
#    'aid': '4761',
#    'readTimeLength': '63',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,4761)'},
#   {'id': 'r26655',
#    'aid': '6916',
#    'readTimeLength': '76',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,6916)'},
#   {'id': 'r43896',
#    'aid': '7237',
#    'readTimeLength': '87',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,7237)'},
#   {'id': 'r50732',
#    'aid': '5583',
#    'readTimeLength': '40',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '1',
#    'commentDetail': 'comments to this article: (1,5583)'},
#   {'id': 'r50288',
#    'aid': '4817',
#    'readTimeLength': '64',
#    'agreeOrNot': '1',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,4817)'},
#   {'id': 'r50549',
#    'aid': '9914',
#    'readTimeLength': '94',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '1',
#    'commentDetail': 'comments to this article: (1,9914)'},
#   {'id': 'r55886',
#    'aid': '4007',
#    'readTimeLength': '86',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '1',
#    'commentDetail': 'comments to this article: (1,4007)'},
#   {'id': 'r57434',
#    'aid': '7124',
#    'readTimeLength': '17',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,7124)'},
#   {'id': 'r59103',
#    'aid': '9184',
#    'readTimeLength': '15',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,9184)'},
#   {'id': 'r86142',
#    'aid': '4692',
#    'readTimeLength': '43',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,4692)'},
#   {'id': 'r100593',
#    'aid': '7809',
#    'readTimeLength': '57',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,7809)'},
#   {'id': 'r100443',
#    'aid': '2314',
#    'readTimeLength': '38',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,2314)'},
#   {'id': 'r105345',
#    'aid': '4270',
#    'readTimeLength': '27',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,4270)'},
#   {'id': 'r105540',
#    'aid': '1090',
#    'readTimeLength': '62',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '1',
#    'commentDetail': 'comments to this article: (1,1090)'},
#   {'id': 'r106876',
#    'aid': '6043',
#    'readTimeLength': '33',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,6043)'},
#   {'id': 'r122493',
#    'aid': '1965',
#    'readTimeLength': '38',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '1',
#    'commentDetail': 'comments to this article: (1,1965)'},
#   {'id': 'r127965',
#    'aid': '3912',
#    'readTimeLength': '63',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,3912)'},
#   {'id': 'r143372',
#    'aid': '9834',
#    'readTimeLength': '74',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,9834)'},
#   {'id': 'r173797',
#    'aid': '807',
#    'readTimeLength': '37',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,807)'},
#   {'id': 'r184173',
#    'aid': '709',
#    'readTimeLength': '86',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,709)'},
#   {'id': 'r197009',
#    'aid': '8213',
#    'readTimeLength': '36',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,8213)'},
#   {'id': 'r200046',
#    'aid': '9107',
#    'readTimeLength': '33',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,9107)'},
#   {'id': 'r201266',
#    'aid': '6033',
#    'readTimeLength': '88',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '1',
#    'commentDetail': 'comments to this article: (1,6033)'},
#   {'id': 'r215742',
#    'aid': '1453',
#    'readTimeLength': '80',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '1',
#    'commentDetail': 'comments to this article: (1,1453)'},
#   {'id': 'r219770',
#    'aid': '3337',
#    'readTimeLength': '36',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,3337)'},
#   {'id': 'r230815',
#    'aid': '2882',
#    'readTimeLength': '5',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,2882)'},
#   {'id': 'r231164',
#    'aid': '1540',
#    'readTimeLength': '13',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,1540)'},
#   {'id': 'r234280',
#    'aid': '8525',
#    'readTimeLength': '77',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,8525)'},
#   {'id': 'r249473',
#    'aid': '1139',
#    'readTimeLength': '30',
#    'agreeOrNot': '1',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,1139)'},
#   {'id': 'r252183',
#    'aid': '314',
#    'readTimeLength': '36',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,314)'},
#   {'id': 'r254300',
#    'aid': '2922',
#    'readTimeLength': '30',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '1',
#    'commentDetail': 'comments to this article: (1,2922)'},
#   {'id': 'r256202',
#    'aid': '2068',
#    'readTimeLength': '50',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '1',
#    'commentDetail': 'comments to this article: (1,2068)'},
#   {'id': 'r269822',
#    'aid': '154',
#    'readTimeLength': '46',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,154)'},
#   {'id': 'r273872',
#    'aid': '5689',
#    'readTimeLength': '68',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,5689)'},
#   {'id': 'r294693',
#    'aid': '6635',
#    'readTimeLength': '38',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '1',
#    'commentDetail': 'comments to this article: (1,6635)'},
#   {'id': 'r307579',
#    'aid': '9618',
#    'readTimeLength': '95',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,9618)'},
#   {'id': 'r312445',
#    'aid': '1249',
#    'readTimeLength': '0',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,1249)'},
#   {'id': 'r317520',
#    'aid': '4867',
#    'readTimeLength': '48',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,4867)'},
#   {'id': 'r327088',
#    'aid': '5891',
#    'readTimeLength': '93',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,5891)'},
#   {'id': 'r334844',
#    'aid': '4706',
#    'readTimeLength': '9',
#    'agreeOrNot': '1',
#    'commentOrNot': '1',
#    'shareOrNot': '1',
#    'commentDetail': 'comments to this article: (1,4706)'},
#   {'id': 'r346826',
#    'aid': '3972',
#    'readTimeLength': '62',
#    'agreeOrNot': '1',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,3972)'},
#   {'id': 'r349830',
#    'aid': '9639',
#    'readTimeLength': '36',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '1',
#    'commentDetail': 'comments to this article: (1,9639)'},
#   {'id': 'r353741',
#    'aid': '5405',
#    'readTimeLength': '54',
#    'agreeOrNot': '1',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,5405)'},
#   {'id': 'r353686',
#    'aid': '320',
#    'readTimeLength': '66',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,320)'},
#   {'id': 'r373029',
#    'aid': '6513',
#    'readTimeLength': '26',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,6513)'},
#   {'id': 'r376886',
#    'aid': '4283',
#    'readTimeLength': '53',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,4283)'},
#   {'id': 'r399713',
#    'aid': '465',
#    'readTimeLength': '11',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,465)'},
#   {'id': 'r410573',
#    'aid': '230',
#    'readTimeLength': '56',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,230)'},
#   {'id': 'r417322',
#    'aid': '1874',
#    'readTimeLength': '55',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,1874)'},
#   {'id': 'r420941',
#    'aid': '9992',
#    'readTimeLength': '65',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,9992)'},
#   {'id': 'r436135',
#    'aid': '3850',
#    'readTimeLength': '89',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,3850)'},
#   {'id': 'r442618',
#    'aid': '3687',
#    'readTimeLength': '99',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,3687)'},
#   {'id': 'r445942',
#    'aid': '4753',
#    'readTimeLength': '53',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,4753)'},
#   {'id': 'r463093',
#    'aid': '2292',
#    'readTimeLength': '33',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,2292)'},
#   {'id': 'r464417',
#    'aid': '7691',
#    'readTimeLength': '17',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,7691)'},
#   {'id': 'r484118',
#    'aid': '65',
#    'readTimeLength': '79',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,65)'},
#   {'id': 'r504019',
#    'aid': '9176',
#    'readTimeLength': '21',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,9176)'},
#   {'id': 'r509337',
#    'aid': '7572',
#    'readTimeLength': '11',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,7572)'},
#   {'id': 'r516180',
#    'aid': '8977',
#    'readTimeLength': '64',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,8977)'},
#   {'id': 'r528085',
#    'aid': '6711',
#    'readTimeLength': '20',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,6711)'},
#   {'id': 'r531079',
#    'aid': '1491',
#    'readTimeLength': '49',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,1491)'},
#   {'id': 'r538423',
#    'aid': '3639',
#    'readTimeLength': '62',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,3639)'},
#   {'id': 'r547850',
#    'aid': '5658',
#    'readTimeLength': '14',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,5658)'},
#   {'id': 'r569433',
#    'aid': '8747',
#    'readTimeLength': '54',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,8747)'},
#   {'id': 'r571288',
#    'aid': '2840',
#    'readTimeLength': '83',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,2840)'},
#   {'id': 'r594631',
#    'aid': '5662',
#    'readTimeLength': '86',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,5662)'},
#   {'id': 'r631177',
#    'aid': '9762',
#    'readTimeLength': '37',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '1',
#    'commentDetail': 'comments to this article: (1,9762)'},
#   {'id': 'r633879',
#    'aid': '7269',
#    'readTimeLength': '36',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,7269)'},
#   {'id': 'r636114',
#    'aid': '5169',
#    'readTimeLength': '37',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,5169)'},
#   {'id': 'r646221',
#    'aid': '1318',
#    'readTimeLength': '81',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,1318)'},
#   {'id': 'r656258',
#    'aid': '9869',
#    'readTimeLength': '90',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,9869)'},
#   {'id': 'r667252',
#    'aid': '8848',
#    'readTimeLength': '52',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,8848)'},
#   {'id': 'r691919',
#    'aid': '6211',
#    'readTimeLength': '10',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,6211)'},
#   {'id': 'r714886',
#    'aid': '2420',
#    'readTimeLength': '12',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,2420)'},
#   {'id': 'r734389',
#    'aid': '1100',
#    'readTimeLength': '56',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,1100)'},
#   {'id': 'r743732',
#    'aid': '2431',
#    'readTimeLength': '9',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,2431)'},
#   {'id': 'r759070',
#    'aid': '5061',
#    'readTimeLength': '92',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,5061)'},
#   {'id': 'r760754',
#    'aid': '2236',
#    'readTimeLength': '95',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,2236)'},
#   {'id': 'r763112',
#    'aid': '480',
#    'readTimeLength': '19',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,480)'},
#   {'id': 'r768617',
#    'aid': '6763',
#    'readTimeLength': '41',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,6763)'},
#   {'id': 'r779389',
#    'aid': '4406',
#    'readTimeLength': '9',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,4406)'},
#   {'id': 'r783926',
#    'aid': '7249',
#    'readTimeLength': '2',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '1',
#    'commentDetail': 'comments to this article: (1,7249)'},
#   {'id': 'r790160',
#    'aid': '7180',
#    'readTimeLength': '27',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,7180)'},
#   {'id': 'r807992',
#    'aid': '4336',
#    'readTimeLength': '99',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,4336)'},
#   {'id': 'r821598',
#    'aid': '7004',
#    'readTimeLength': '79',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,7004)'},
#   {'id': 'r825754',
#    'aid': '1920',
#    'readTimeLength': '96',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,1920)'},
#   {'id': 'r837576',
#    'aid': '369',
#    'readTimeLength': '88',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,369)'},
#   {'id': 'r847498',
#    'aid': '2930',
#    'readTimeLength': '0',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,2930)'},
#   {'id': 'r857905',
#    'aid': '7786',
#    'readTimeLength': '34',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,7786)'},
#   {'id': 'r863835',
#    'aid': '4825',
#    'readTimeLength': '49',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,4825)'},
#   {'id': 'r881125',
#    'aid': '1068',
#    'readTimeLength': '21',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,1068)'},
#   {'id': 'r884047',
#    'aid': '8873',
#    'readTimeLength': '96',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,8873)'},
#   {'id': 'r885677',
#    'aid': '5737',
#    'readTimeLength': '10',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,5737)'},
#   {'id': 'r899638',
#    'aid': '1162',
#    'readTimeLength': '10',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,1162)'},
#   {'id': 'r931455',
#    'aid': '3807',
#    'readTimeLength': '15',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '1',
#    'commentDetail': 'comments to this article: (1,3807)'},
#   {'id': 'r957155',
#    'aid': '5598',
#    'readTimeLength': '86',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,5598)'},
#   {'id': 'r962263',
#    'aid': '818',
#    'readTimeLength': '36',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,818)'},
#   {'id': 'r967902',
#    'aid': '6822',
#    'readTimeLength': '42',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,6822)'},
#   {'id': 'r975552',
#    'aid': '414',
#    'readTimeLength': '57',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '1',
#    'commentDetail': 'comments to this article: (1,414)'},
#   {'id': 'r988083',
#    'aid': '1517',
#    'readTimeLength': '31',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,1517)'},
#   {'id': 'r999920',
#    'aid': '7791',
#    'readTimeLength': '17',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,7791)'},
#   {'id': 'r13790',
#    'aid': '3643',
#    'readTimeLength': '24',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,3643)'},
#   {'id': 'r17715',
#    'aid': '4761',
#    'readTimeLength': '63',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,4761)'},
#   {'id': 'r26655',
#    'aid': '6916',
#    'readTimeLength': '76',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,6916)'},
#   {'id': 'r43896',
#    'aid': '7237',
#    'readTimeLength': '87',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,7237)'},
#   {'id': 'r50549',
#    'aid': '9914',
#    'readTimeLength': '94',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '1',
#    'commentDetail': 'comments to this article: (1,9914)'},
#   {'id': 'r50288',
#    'aid': '4817',
#    'readTimeLength': '64',
#    'agreeOrNot': '1',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,4817)'},
#   {'id': 'r50732',
#    'aid': '5583',
#    'readTimeLength': '40',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '1',
#    'commentDetail': 'comments to this article: (1,5583)'},
#   {'id': 'r55886',
#    'aid': '4007',
#    'readTimeLength': '86',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '1',
#    'commentDetail': 'comments to this article: (1,4007)'},
#   {'id': 'r57434',
#    'aid': '7124',
#    'readTimeLength': '17',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,7124)'},
#   {'id': 'r59103',
#    'aid': '9184',
#    'readTimeLength': '15',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,9184)'},
#   {'id': 'r86142',
#    'aid': '4692',
#    'readTimeLength': '43',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,4692)'},
#   {'id': 'r100443',
#    'aid': '2314',
#    'readTimeLength': '38',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,2314)'},
#   {'id': 'r100593',
#    'aid': '7809',
#    'readTimeLength': '57',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,7809)'},
#   {'id': 'r105345',
#    'aid': '4270',
#    'readTimeLength': '27',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,4270)'},
#   {'id': 'r105540',
#    'aid': '1090',
#    'readTimeLength': '62',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '1',
#    'commentDetail': 'comments to this article: (1,1090)'},
#   {'id': 'r106876',
#    'aid': '6043',
#    'readTimeLength': '33',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,6043)'},
#   {'id': 'r122493',
#    'aid': '1965',
#    'readTimeLength': '38',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '1',
#    'commentDetail': 'comments to this article: (1,1965)'},
#   {'id': 'r127965',
#    'aid': '3912',
#    'readTimeLength': '63',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,3912)'},
#   {'id': 'r143372',
#    'aid': '9834',
#    'readTimeLength': '74',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,9834)'},
#   {'id': 'r173797',
#    'aid': '807',
#    'readTimeLength': '37',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,807)'},
#   {'id': 'r184173',
#    'aid': '709',
#    'readTimeLength': '86',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,709)'},
#   {'id': 'r197009',
#    'aid': '8213',
#    'readTimeLength': '36',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,8213)'},
#   {'id': 'r200046',
#    'aid': '9107',
#    'readTimeLength': '33',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,9107)'},
#   {'id': 'r201266',
#    'aid': '6033',
#    'readTimeLength': '88',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '1',
#    'commentDetail': 'comments to this article: (1,6033)'},
#   {'id': 'r215742',
#    'aid': '1453',
#    'readTimeLength': '80',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '1',
#    'commentDetail': 'comments to this article: (1,1453)'},
#   {'id': 'r219770',
#    'aid': '3337',
#    'readTimeLength': '36',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,3337)'},
#   {'id': 'r230815',
#    'aid': '2882',
#    'readTimeLength': '5',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,2882)'},
#   {'id': 'r231164',
#    'aid': '1540',
#    'readTimeLength': '13',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,1540)'},
#   {'id': 'r234280',
#    'aid': '8525',
#    'readTimeLength': '77',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,8525)'},
#   {'id': 'r249473',
#    'aid': '1139',
#    'readTimeLength': '30',
#    'agreeOrNot': '1',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,1139)'},
#   {'id': 'r252183',
#    'aid': '314',
#    'readTimeLength': '36',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,314)'},
#   {'id': 'r254300',
#    'aid': '2922',
#    'readTimeLength': '30',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '1',
#    'commentDetail': 'comments to this article: (1,2922)'},
#   {'id': 'r256202',
#    'aid': '2068',
#    'readTimeLength': '50',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '1',
#    'commentDetail': 'comments to this article: (1,2068)'},
#   {'id': 'r269822',
#    'aid': '154',
#    'readTimeLength': '46',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,154)'},
#   {'id': 'r273872',
#    'aid': '5689',
#    'readTimeLength': '68',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,5689)'},
#   {'id': 'r294693',
#    'aid': '6635',
#    'readTimeLength': '38',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '1',
#    'commentDetail': 'comments to this article: (1,6635)'},
#   {'id': 'r307579',
#    'aid': '9618',
#    'readTimeLength': '95',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,9618)'},
#   {'id': 'r312445',
#    'aid': '1249',
#    'readTimeLength': '0',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,1249)'},
#   {'id': 'r317520',
#    'aid': '4867',
#    'readTimeLength': '48',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,4867)'},
#   {'id': 'r327088',
#    'aid': '5891',
#    'readTimeLength': '93',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,5891)'},
#   {'id': 'r334844',
#    'aid': '4706',
#    'readTimeLength': '9',
#    'agreeOrNot': '1',
#    'commentOrNot': '1',
#    'shareOrNot': '1',
#    'commentDetail': 'comments to this article: (1,4706)'},
#   {'id': 'r346826',
#    'aid': '3972',
#    'readTimeLength': '62',
#    'agreeOrNot': '1',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,3972)'},
#   {'id': 'r349830',
#    'aid': '9639',
#    'readTimeLength': '36',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '1',
#    'commentDetail': 'comments to this article: (1,9639)'},
#   {'id': 'r353686',
#    'aid': '320',
#    'readTimeLength': '66',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,320)'},
#   {'id': 'r353741',
#    'aid': '5405',
#    'readTimeLength': '54',
#    'agreeOrNot': '1',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,5405)'},
#   {'id': 'r373029',
#    'aid': '6513',
#    'readTimeLength': '26',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,6513)'},
#   {'id': 'r376886',
#    'aid': '4283',
#    'readTimeLength': '53',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,4283)'},
#   {'id': 'r399713',
#    'aid': '465',
#    'readTimeLength': '11',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,465)'},
#   {'id': 'r410573',
#    'aid': '230',
#    'readTimeLength': '56',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,230)'},
#   {'id': 'r417322',
#    'aid': '1874',
#    'readTimeLength': '55',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,1874)'},
#   {'id': 'r420941',
#    'aid': '9992',
#    'readTimeLength': '65',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,9992)'},
#   {'id': 'r436135',
#    'aid': '3850',
#    'readTimeLength': '89',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,3850)'},
#   {'id': 'r442618',
#    'aid': '3687',
#    'readTimeLength': '99',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,3687)'},
#   {'id': 'r445942',
#    'aid': '4753',
#    'readTimeLength': '53',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,4753)'},
#   {'id': 'r463093',
#    'aid': '2292',
#    'readTimeLength': '33',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,2292)'},
#   {'id': 'r464417',
#    'aid': '7691',
#    'readTimeLength': '17',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,7691)'},
#   {'id': 'r484118',
#    'aid': '65',
#    'readTimeLength': '79',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,65)'},
#   {'id': 'r504019',
#    'aid': '9176',
#    'readTimeLength': '21',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,9176)'},
#   {'id': 'r509337',
#    'aid': '7572',
#    'readTimeLength': '11',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,7572)'},
#   {'id': 'r516180',
#    'aid': '8977',
#    'readTimeLength': '64',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,8977)'},
#   {'id': 'r528085',
#    'aid': '6711',
#    'readTimeLength': '20',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,6711)'},
#   {'id': 'r531079',
#    'aid': '1491',
#    'readTimeLength': '49',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,1491)'},
#   {'id': 'r538423',
#    'aid': '3639',
#    'readTimeLength': '62',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,3639)'},
#   {'id': 'r547850',
#    'aid': '5658',
#    'readTimeLength': '14',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,5658)'},
#   {'id': 'r569433',
#    'aid': '8747',
#    'readTimeLength': '54',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,8747)'},
#   {'id': 'r571288',
#    'aid': '2840',
#    'readTimeLength': '83',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,2840)'},
#   {'id': 'r594631',
#    'aid': '5662',
#    'readTimeLength': '86',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,5662)'},
#   {'id': 'r631177',
#    'aid': '9762',
#    'readTimeLength': '37',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '1',
#    'commentDetail': 'comments to this article: (1,9762)'},
#   {'id': 'r633879',
#    'aid': '7269',
#    'readTimeLength': '36',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,7269)'},
#   {'id': 'r636114',
#    'aid': '5169',
#    'readTimeLength': '37',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,5169)'},
#   {'id': 'r646221',
#    'aid': '1318',
#    'readTimeLength': '81',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,1318)'},
#   {'id': 'r656258',
#    'aid': '9869',
#    'readTimeLength': '90',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,9869)'},
#   {'id': 'r667252',
#    'aid': '8848',
#    'readTimeLength': '52',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,8848)'},
#   {'id': 'r691919',
#    'aid': '6211',
#    'readTimeLength': '10',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,6211)'},
#   {'id': 'r714886',
#    'aid': '2420',
#    'readTimeLength': '12',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,2420)'},
#   {'id': 'r734389',
#    'aid': '1100',
#    'readTimeLength': '56',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,1100)'},
#   {'id': 'r743732',
#    'aid': '2431',
#    'readTimeLength': '9',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,2431)'},
#   {'id': 'r759070',
#    'aid': '5061',
#    'readTimeLength': '92',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,5061)'},
#   {'id': 'r760754',
#    'aid': '2236',
#    'readTimeLength': '95',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,2236)'},
#   {'id': 'r763112',
#    'aid': '480',
#    'readTimeLength': '19',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,480)'},
#   {'id': 'r768617',
#    'aid': '6763',
#    'readTimeLength': '41',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,6763)'},
#   {'id': 'r779389',
#    'aid': '4406',
#    'readTimeLength': '9',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,4406)'},
#   {'id': 'r783926',
#    'aid': '7249',
#    'readTimeLength': '2',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '1',
#    'commentDetail': 'comments to this article: (1,7249)'},
#   {'id': 'r790160',
#    'aid': '7180',
#    'readTimeLength': '27',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,7180)'},
#   {'id': 'r807992',
#    'aid': '4336',
#    'readTimeLength': '99',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,4336)'},
#   {'id': 'r821598',
#    'aid': '7004',
#    'readTimeLength': '79',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,7004)'},
#   {'id': 'r825754',
#    'aid': '1920',
#    'readTimeLength': '96',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,1920)'},
#   {'id': 'r837576',
#    'aid': '369',
#    'readTimeLength': '88',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,369)'},
#   {'id': 'r847498',
#    'aid': '2930',
#    'readTimeLength': '0',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,2930)'},
#   {'id': 'r857905',
#    'aid': '7786',
#    'readTimeLength': '34',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,7786)'},
#   {'id': 'r863835',
#    'aid': '4825',
#    'readTimeLength': '49',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,4825)'},
#   {'id': 'r881125',
#    'aid': '1068',
#    'readTimeLength': '21',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,1068)'},
#   {'id': 'r884047',
#    'aid': '8873',
#    'readTimeLength': '96',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,8873)'},
#   {'id': 'r885677',
#    'aid': '5737',
#    'readTimeLength': '10',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,5737)'},
#   {'id': 'r899638',
#    'aid': '1162',
#    'readTimeLength': '10',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,1162)'},
#   {'id': 'r931455',
#    'aid': '3807',
#    'readTimeLength': '15',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '1',
#    'commentDetail': 'comments to this article: (1,3807)'},
#   {'id': 'r957155',
#    'aid': '5598',
#    'readTimeLength': '86',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,5598)'},
#   {'id': 'r962263',
#    'aid': '818',
#    'readTimeLength': '36',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,818)'},
#   {'id': 'r967902',
#    'aid': '6822',
#    'readTimeLength': '42',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,6822)'},
#   {'id': 'r975552',
#    'aid': '414',
#    'readTimeLength': '57',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '1',
#    'commentDetail': 'comments to this article: (1,414)'},
#   {'id': 'r988083',
#    'aid': '1517',
#    'readTimeLength': '31',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,1517)'},
#   {'id': 'r999920',
#    'aid': '7791',
#    'readTimeLength': '17',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,7791)'}]}

# %%
user_handler = UserTableHandler(db_handler)
# json_file = "../db-generation/user.dat"
# user_handler.bulk_insert(json_file)
# Out:
# Inserted 5000 records into User
# Inserted 5000 records into User
# Finished processing 10000 records.
# Execution time: 0:00:00.328359

# %%
len(user_handler.fetch_users({"region": "Beijing"}))
# Out:
# 100

# %%
article_handler = ArticleTableHandler(db_handler)
# json_file = "../db-generation/article.dat"
# article_handler.bulk_insert(json_file)

# %%
article_handler.fetch_articles({"aid": "1840"})
# Out:
# [{'_id': ObjectId('6755645be0c02c6b60556e2d'),
#   'id': 'a1840',
#   'timestamp': '1506000001840',
#   'aid': '1840',
#   'title': 'title1840',
#   'category': 'technology',
#   'abstract': 'abstract of article 1840',
#   'articleTags': 'tags21',
#   'authors': 'author189',
#   'language': 'en',
#   'text': 'text_a1840.txt',
#   'image': 'image_a1840_0.jpg,',
#   'video': ''}]

# %%
read_handler = ReadTableHandler(db_handler)
read_handler.bulk_insert("../db-generation/read.dat")

# be_read_handler = BeReadTableHandler(db_handler)
# be_read_handler.bulk_insert("../db-generation/beRead.dat")
# Out:
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Finished processing 1000000 records.
# Execution time: 0:01:03.126531

# %%
# read_handler.fetch_user_reads("1")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 read_handler.fetch_user_reads("1")
#
# AttributeError: 'ReadTableHandler' object has no attribute 'fetch_user_reads'

# %%
read_handler.fetch_reads_with_details()
# Out:
# [{'_id': ObjectId('67556462e0c02c6b60559c48'),
#   'timestamp': '1506332297000',
#   'id': 'r0',
#   'uid': '5610',
#   'aid': '5594',
#   'readTimeLength': '71',
#   'agreeOrNot': '0',
#   'commentOrNot': '1',
#   'shareOrNot': '0',
#   'commentDetail': 'comments to this article: (5610,5594)',
#   'region': 'Beijing',
#   'article_details': [],
#   'user_details': []},
#  {'_id': ObjectId('67556462e0c02c6b60559c49'),
#   'timestamp': '1506332307000',
#   'id': 'r1',
#   'uid': '8926',
#   'aid': '836',
#   'readTimeLength': '65',
#   'agreeOrNot': '0',
#   'commentOrNot': '0',
#   'shareOrNot': '0',
#   'commentDetail': 'comments to this article: (8926,836)',
#   'region': 'Beijing',
#   'article_details': [],
#   'user_details': []},
#  {'_id': ObjectId('67556462e0c02c6b60559c4a'),
#   'timestamp': '1506332317000',
#   'id': 'r2',
#   'uid': '7664',
#   'aid': '8240',
#   'readTimeLength': '69',
#   'agreeOrNot': '0',
#   'commentOrNot': '0',
#   'shareOrNot': '0',
#   'commentDetail': 'comments to this article: (7664,8240)',
#   'region': 'Beijing',
#   'article_details': [],
#   'user_details': []},
#  {'_id': ObjectId('67556462e0c02c6b60559c4c'),
#   'timestamp': '1506332337000',
#   'id': 'r4',
#   'uid': '5084',
#   'aid': '3647',
#   'readTimeLength': '97',
#   'agreeOrNot': '0',
#   'commentOrNot': '1',
#   'shareOrNot': '0',
#   'commentDetail': 'comments to this article: (5084,3647)',
#   'region': 'Beijing',
#   'article_details': [],
#   'user_details': []},
#  {'_id': ObjectId('67556462e0c02c6b60559c4d'),
#   'timestamp': '1506332347000',
#   'id': 'r5',
#   'uid': '3794',
#   'aid': '3662',
#   'readTimeLength': '90',
#   'agreeOrNot': '0',
#   'commentOrNot': '1',
#   'shareOrNot': '0',
#   'commentDetail': 'comments to this article: (3794,3662)',
#   'region': 'Beijing',
#   'article_details': [],
#   'user_details': []},
#  {'_id': ObjectId('67556462e0c02c6b60559c4f'),
#   'timestamp': '1506332367000',
#   'id': 'r7',
#   'uid': '8550',
#   'aid': '2792',
#   'readTimeLength': '51',
#   'agreeOrNot': '0',
#   'commentOrNot': '0',
#   'shareOrNot': '0',
#   'commentDetail': 'comments to this article: (8550,2792)',
#   'region': 'Beijing',
#   'article_details': [],
#   'user_details': []},
#  {'_id': ObjectId('67556462e0c02c6b60559c50'),
#   'timestamp': '1506332377000',
#   'id': 'r8',
#   'uid': '8285',
#   'aid': '4491',
#   'readTimeLength': '90',
#   'agreeOrNot': '1',
#   'commentOrNot': '1',
#   'shareOrNot': '0',
#   'commentDetail': 'comments to this article: (8285,4491)',
#   'region': 'Beijing',
#   'article_details': [],
#   'user_details': []},
#  {'_id': ObjectId('67556462e0c02c6b60559c54'),
#   'timestamp': '1506332417000',
#   'id': 'r12',
#   'uid': '9129',
#   'aid': '3497',
#   'readTimeLength': '95',
#   'agreeOrNot': '0',
#   'commentOrNot': '0',
#   'shareOrNot': '1',
#   'commentDetail': 'comments to this article: (9129,3497)',
#   'region': 'Beijing',
#   'article_details': [],
#   'user_details': []},
#  {'_id': ObjectId('67556462e0c02c6b60559c56'),
#   'timestamp': '1506332437000',
#   'id': 'r14',
#   'uid': '4697',
#   'aid': '5831',
#   'readTimeLength': '12',
#   'agreeOrNot': '0',
#   'commentOrNot': '0',
#   'shareOrNot': '0',
#   'commentDetail': 'comments to this article: (4697,5831)',
#   'region': 'Beijing',
#   'article_details': [],
#   'user_details': []},
#  {'_id': ObjectId('67556462e0c02c6b60559c5a'),
#   'timestamp': '1506332477000',
#   'id': 'r18',
#   'uid': '952',
#   'aid': '6024',
#   'readTimeLength': '73',
#   'agreeOrNot': '0',
#   'commentOrNot': '0',
#   'shareOrNot': '0',
#   'commentDetail': 'comments to this article: (952,6024)',
#   'region': 'Beijing',
#   'article_details': [],
#   'user_details': []}]
