# %%
import json
from pymongo import MongoClient, errors
from datetime import datetime

# %%
import time
from datetime import datetime
from functools import wraps

def log_execution_time(func):
    """A decorator to log the execution time of a function."""
    @wraps(func)
    def wrapper(*args, **kwargs):
        start_time = datetime.now()
        result = func(*args, **kwargs)
        end_time = datetime.now()
        print(f"Execution time: {end_time - start_time}")
        return result
    return wrapper

def handle_exceptions(func):
    """A decorator to handle exceptions."""
    @wraps(func)
    def wrapper(*args, **kwargs):
        try:
            return func(*args, **kwargs)
        except FileNotFoundError as e:
            print(f"Error: File not found - {e}")
        except Exception as e:
            print(f"Error occurred in '{func.__name__}': {e}")
    return wrapper

# %%
class MongoDBHandler:
    """Handles MongoDB operations."""

    def __init__(self, host: str, port: int):
        """Initialize the MongoDB connection."""
        try:
            self.client = MongoClient(host, port)
            print(f"Connected to MongoDB at {host}:{port}")
            
            self.user_collection = self.client["userDatabase"]["User"]
            self.article_collection = self.client["articleDatabase"]["Article"]
            self.read_collection = self.client["readDatabase"]["Read"]
            self.be_read_collection = self.client["beReadDatabase"]["BeRead"]
            self.popular_rank_collection = self.client["popularRankDatabase"]["PopularRank"]
            
        except errors.ConnectionFailure as e:
            print(f"Error connecting to MongoDB: {e}")
            raise

    def get_database(self, db_name: str):
        """Retrieve a database."""
        return self.client[db_name]

# %%
class TableHandler:
    """Base class for handling common database operations."""    
    def __init__(self, collection):
        """Initialize with a MongoDB collection."""
        self.collection = collection
    
    @handle_exceptions
    @log_execution_time
    def bulk_insert(self, json_file: str, batch_size: int = 5000):
        """
        Bulk inserts data from a JSON file into the MongoDB collection.
        Uses the duplication_logic method for optional record transformation.
        """
        with open(json_file, 'r', encoding='utf-8') as file:
            buffer = []
            count = 0
            for line in file:
                record = json.loads(line)
                # Apply duplication logic (can be overridden in subclasses)
                records = self._process_record(record)
                buffer.extend(records)
                count += 1
                # Bulk write when buffer reaches batch_size
                if len(buffer) >= batch_size:
                    self._write_to_db(buffer)
                    buffer = []
            # Final flush of any remaining records
            if buffer:
                self._write_to_db(buffer)
        print(f"Finished processing {count} records.")

    def _process_record(self, record):
        """
        Default process record logic: No special handling.
        Override this method in subclasses for custom logic.
        """
        return [record]
    
    def _write_to_db(self, data):
        """Write data to the specified collection."""
        try:
            result = self.collection.insert_many(data, ordered=False)
            print(f"Inserted {len(result.inserted_ids)} records into {self.collection.name}")
        except errors.BulkWriteError as e:
            print(f"Error during bulk insert: {e.details}")

# %%
cache = {}

class UserTableHandler(TableHandler):
    def __init__(self, db_handler: MongoDBHandler):
        super().__init__(db_handler.user_collection)
        
    def get_region_by_uid(self, uid):
        if uid in cache:
            return cache[uid]
        else:
            user = self.collection.find_one({"uid": uid})
            cache[uid] = user.get("region") if user else None
        return cache[uid]
    
    def fetch_users(self, conditions={}, count=100, offset=0):
        if count == None:
            users = self.collection.find(conditions, { "_id": 0, "timestamp": 0, "id": 0 })
        else:
            users = self.collection.find(conditions, { "_id": 0, "timestamp": 0, "id": 0 }).skip(offset).limit(count)
        return list(users)
    
    def fetch_users_by_region(self, region: str, count=100, offset=0):
        return self.fetch_users({"region": region}, count, offset)
        
class ArticleTableHandler(TableHandler):
    def __init__(self, db_handler: MongoDBHandler):
        super().__init__(db_handler.article_collection)

    def _process_record(self, record):
        if record.get("category") == "science":
            r1 = record.copy()
            r2 = record.copy()
            r1["shardCopy"] = 1
            r2["shardCopy"] = 2
            return [r1, r2]
        return [record]
    
    def fetch_articles(self, conditions={}, count=100, offset=0):
        pipeline = [
            {
                "$match": conditions
            },
            {
                "$group": {
                    "_id": "$aid",  # Group by the unique identifier
                    "deduplicatedDoc": { "$first": "$$ROOT" }
                }
            },
            {
                "$replaceRoot": { "newRoot": "$deduplicatedDoc" }
            }
        ]
        if count != None:
            pipeline.append({"$skip": offset})
            pipeline.append({"$limit": count})

        articles = self.collection.aggregate(pipeline)
        return list(articles)
    
    def fetch_articles_by_category(self, category: str, count=100, offset=0):
        return self.fetch_articles({"category": category}, count, offset)
    
class ReadTableHandler(TableHandler):
    def __init__(self, db_handler: MongoDBHandler):
        super().__init__(db_handler.read_collection)
        self.userTableHandler = UserTableHandler(db_handler)
        
    def _process_record(self, record):
        region = self.userTableHandler.get_region_by_uid(record['uid'])
        record['region'] = region
        return [record]

    def fetch_reads(self, conditions={}, count=100, offset=0):
        ### time check, when feaching beijing user's reads. 
        ### implementation: read with added region field, which is the shard key
        fields = {
                    "_id": 0,
                    "timestamp": 0,
                    "uid": 0,
                    "region": 0
                }
        if count == None:
            reads = self.collection.find(conditions, fields)
        else:
            reads = self.collection.find(conditions, fields).skip(offset).limit(count)
        return list(reads)
    
    def fetch_reads_by_user(self, uid: int):
        return self.fetch_reads({"uid": uid}, None, None)
    
    
    def fetch_aggregated_reads_by_category(self, category: str):
        limit = 10
        """
        Aggregate reads for a specific article category.
        """
        pipeline = [
            {
                "$lookup": {
                    "from": "articleDatabase.Article",
                    "localField": "aid",
                    "foreignField": "aid",
                    "as": "article_details",
                }
            },
            {"$unwind": "$article_details"},  # Flatten the article details array
            {"$match": {"article_details.category": category}},  # Filter condition
            {"$group": {"_id": "$uid", "total_reads": {"$sum": 1}}},  # Group by user
            {"$limit": limit},
        ]
        return list(self.collection.aggregate(pipeline))
    
    def fetch_reads_with_details(self):
        limit = 10
        """
        Fetch reads with user and article details.
        Simulates a join between Reads, User, and Article collections.
        """
        pipeline = [
            {
                "$lookup": {
                    "from": "articleDatabase.Article",
                    "localField": "aid",
                    "foreignField": "aid",
                    "as": "article_details",
                }
            },
            {
                "$lookup": {
                    "from": "userDatabase.User",
                    "localField": "uid",
                    "foreignField": "uid",
                    "as": "user_details",
                }
            },
            {"$limit": limit},
        ]
        return list(self.collection.aggregate(pipeline))
    
    
        
class BeReadTableHandler(TableHandler):
    def __init__(self, db_handler: MongoDBHandler):
        super().__init__(db_handler.be_read_collection)
        self.userTableHandler = UserTableHandler(db_handler)
        
        
class PopularRankTableHandler(TableHandler):
    def __init__(self, db_handler: MongoDBHandler):
        super().__init__(db_handler.popular_rank_collection)
        
        
class QueryHandeler():
    def __init__(self, db_handler: MongoDBHandler):
        self.userTableHandler = UserTableHandler(db_handler)
        self.articleTableHandler = ArticleTableHandler(db_handler)
        self.readTableHandler = ReadTableHandler(db_handler)
        self.beReadTableHandler = BeReadTableHandler(db_handler)
        self.popularRankTableHandler = PopularRankTableHandler(db_handler)
        
    def fetch_users(self, conditions={}, count=100, offset=0):
        return self.userTableHandler.fetch_users(conditions, count, offset)
    
    def fetch_users_by_region(self, region: str, count=100, offset=0):
        return self.userTableHandler.fetch_users_by_region(region, count, offset)
    
    def fetch_articles(self, conditions={}, count=100, offset=0):
        return self.articleTableHandler.fetch_articles(conditions, count, offset)
    
    def fetch_articles_by_category(self, category: str, count=100, offset=0):
        return self.articleTableHandler.fetch_articles_by_category(category, count, offset)
    
    def fetch_reads(self, conditions={}, count=100, offset=0):
        return self.readTableHandler.fetch_reads(conditions, count, offset)
    
    def fetch_user_read(self, uid: str):
        user = self.userTableHandler.fetch_users({"uid": uid})
        print(user)
        reads = self.readTableHandler.fetch_reads_by_user(uid)   
        return {
            "user": user,
            "reads": reads
        }
        
        
    # 3) Populate the empty Be-Read table by inserting newly computed records into the
    # Be-Read table.
    # 4) Query the top-5 daily/weekly/monthly popular articles with articles details (text,
    # image, and video if existing) (involving the join of Be-Read table and Article
    # table)

# %%
# Configuration
host = "localhost"
port = 60000
db_handler = MongoDBHandler(host, port)
# Out:
# Connected to MongoDB at localhost:60000

# %%
q = QueryHandeler(db_handler)
q.fetch_user_read("1")
# Out:
# []
# {'user': [],
#  'reads': [{'id': 'r953',
#    'aid': '6322',
#    'readTimeLength': '35',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,6322)'},
#   {'id': 'r10313',
#    'aid': '8411',
#    'readTimeLength': '43',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,8411)'},
#   {'id': 'r17779',
#    'aid': '2974',
#    'readTimeLength': '38',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,2974)'},
#   {'id': 'r24719',
#    'aid': '8804',
#    'readTimeLength': '70',
#    'agreeOrNot': '1',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,8804)'},
#   {'id': 'r29358',
#    'aid': '3151',
#    'readTimeLength': '44',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,3151)'},
#   {'id': 'r29880',
#    'aid': '2571',
#    'readTimeLength': '13',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '1',
#    'commentDetail': 'comments to this article: (1,2571)'},
#   {'id': 'r33630',
#    'aid': '4903',
#    'readTimeLength': '52',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,4903)'},
#   {'id': 'r41959',
#    'aid': '36',
#    'readTimeLength': '54',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,36)'},
#   {'id': 'r45209',
#    'aid': '1335',
#    'readTimeLength': '36',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,1335)'},
#   {'id': 'r64233',
#    'aid': '4887',
#    'readTimeLength': '11',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '1',
#    'commentDetail': 'comments to this article: (1,4887)'},
#   {'id': 'r66298',
#    'aid': '4812',
#    'readTimeLength': '7',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,4812)'},
#   {'id': 'r67135',
#    'aid': '3864',
#    'readTimeLength': '38',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,3864)'},
#   {'id': 'r94869',
#    'aid': '3034',
#    'readTimeLength': '8',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,3034)'},
#   {'id': 'r100642',
#    'aid': '241',
#    'readTimeLength': '40',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '1',
#    'commentDetail': 'comments to this article: (1,241)'},
#   {'id': 'r101155',
#    'aid': '239',
#    'readTimeLength': '87',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,239)'},
#   {'id': 'r106596',
#    'aid': '6626',
#    'readTimeLength': '24',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '1',
#    'commentDetail': 'comments to this article: (1,6626)'},
#   {'id': 'r110924',
#    'aid': '5723',
#    'readTimeLength': '41',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,5723)'},
#   {'id': 'r117210',
#    'aid': '1671',
#    'readTimeLength': '4',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,1671)'},
#   {'id': 'r130038',
#    'aid': '7803',
#    'readTimeLength': '12',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,7803)'},
#   {'id': 'r135124',
#    'aid': '4999',
#    'readTimeLength': '53',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,4999)'},
#   {'id': 'r143074',
#    'aid': '8667',
#    'readTimeLength': '20',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,8667)'},
#   {'id': 'r143670',
#    'aid': '9971',
#    'readTimeLength': '63',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,9971)'},
#   {'id': 'r158202',
#    'aid': '9410',
#    'readTimeLength': '46',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,9410)'},
#   {'id': 'r175377',
#    'aid': '6453',
#    'readTimeLength': '85',
#    'agreeOrNot': '1',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,6453)'},
#   {'id': 'r188711',
#    'aid': '749',
#    'readTimeLength': '50',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,749)'},
#   {'id': 'r188885',
#    'aid': '3695',
#    'readTimeLength': '6',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,3695)'},
#   {'id': 'r198826',
#    'aid': '1649',
#    'readTimeLength': '67',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,1649)'},
#   {'id': 'r198914',
#    'aid': '7278',
#    'readTimeLength': '67',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,7278)'},
#   {'id': 'r218987',
#    'aid': '2820',
#    'readTimeLength': '39',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '1',
#    'commentDetail': 'comments to this article: (1,2820)'},
#   {'id': 'r223093',
#    'aid': '736',
#    'readTimeLength': '66',
#    'agreeOrNot': '1',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,736)'},
#   {'id': 'r227707',
#    'aid': '2010',
#    'readTimeLength': '63',
#    'agreeOrNot': '1',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,2010)'},
#   {'id': 'r241477',
#    'aid': '9969',
#    'readTimeLength': '99',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,9969)'},
#   {'id': 'r246449',
#    'aid': '3938',
#    'readTimeLength': '64',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,3938)'},
#   {'id': 'r256083',
#    'aid': '560',
#    'readTimeLength': '5',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,560)'},
#   {'id': 'r277295',
#    'aid': '5854',
#    'readTimeLength': '53',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,5854)'},
#   {'id': 'r285143',
#    'aid': '2024',
#    'readTimeLength': '17',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '1',
#    'commentDetail': 'comments to this article: (1,2024)'},
#   {'id': 'r292616',
#    'aid': '9365',
#    'readTimeLength': '2',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,9365)'},
#   {'id': 'r298467',
#    'aid': '4888',
#    'readTimeLength': '30',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,4888)'},
#   {'id': 'r302639',
#    'aid': '3777',
#    'readTimeLength': '32',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,3777)'},
#   {'id': 'r331170',
#    'aid': '4535',
#    'readTimeLength': '88',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,4535)'},
#   {'id': 'r334420',
#    'aid': '5024',
#    'readTimeLength': '82',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,5024)'},
#   {'id': 'r335404',
#    'aid': '9814',
#    'readTimeLength': '65',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,9814)'},
#   {'id': 'r340751',
#    'aid': '1259',
#    'readTimeLength': '9',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,1259)'},
#   {'id': 'r345017',
#    'aid': '1866',
#    'readTimeLength': '71',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,1866)'},
#   {'id': 'r356021',
#    'aid': '7966',
#    'readTimeLength': '28',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,7966)'},
#   {'id': 'r388288',
#    'aid': '9446',
#    'readTimeLength': '22',
#    'agreeOrNot': '1',
#    'commentOrNot': '1',
#    'shareOrNot': '1',
#    'commentDetail': 'comments to this article: (1,9446)'},
#   {'id': 'r463077',
#    'aid': '3917',
#    'readTimeLength': '58',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,3917)'},
#   {'id': 'r467319',
#    'aid': '7615',
#    'readTimeLength': '14',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,7615)'},
#   {'id': 'r467995',
#    'aid': '3739',
#    'readTimeLength': '56',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,3739)'},
#   {'id': 'r475707',
#    'aid': '2739',
#    'readTimeLength': '19',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,2739)'},
#   {'id': 'r476904',
#    'aid': '2762',
#    'readTimeLength': '9',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,2762)'},
#   {'id': 'r484262',
#    'aid': '9004',
#    'readTimeLength': '87',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,9004)'},
#   {'id': 'r534185',
#    'aid': '107',
#    'readTimeLength': '42',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '1',
#    'commentDetail': 'comments to this article: (1,107)'},
#   {'id': 'r545160',
#    'aid': '9594',
#    'readTimeLength': '43',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,9594)'},
#   {'id': 'r546686',
#    'aid': '9946',
#    'readTimeLength': '82',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,9946)'},
#   {'id': 'r593348',
#    'aid': '8880',
#    'readTimeLength': '3',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '1',
#    'commentDetail': 'comments to this article: (1,8880)'},
#   {'id': 'r607517',
#    'aid': '8542',
#    'readTimeLength': '47',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '1',
#    'commentDetail': 'comments to this article: (1,8542)'},
#   {'id': 'r623206',
#    'aid': '7324',
#    'readTimeLength': '6',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,7324)'},
#   {'id': 'r642790',
#    'aid': '9084',
#    'readTimeLength': '13',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,9084)'},
#   {'id': 'r663617',
#    'aid': '998',
#    'readTimeLength': '9',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,998)'},
#   {'id': 'r683898',
#    'aid': '2305',
#    'readTimeLength': '84',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,2305)'},
#   {'id': 'r689263',
#    'aid': '9263',
#    'readTimeLength': '66',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,9263)'},
#   {'id': 'r698773',
#    'aid': '6868',
#    'readTimeLength': '1',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,6868)'},
#   {'id': 'r708414',
#    'aid': '7758',
#    'readTimeLength': '53',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '1',
#    'commentDetail': 'comments to this article: (1,7758)'},
#   {'id': 'r713391',
#    'aid': '6838',
#    'readTimeLength': '9',
#    'agreeOrNot': '1',
#    'commentOrNot': '1',
#    'shareOrNot': '1',
#    'commentDetail': 'comments to this article: (1,6838)'},
#   {'id': 'r733051',
#    'aid': '7475',
#    'readTimeLength': '43',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,7475)'},
#   {'id': 'r747060',
#    'aid': '8808',
#    'readTimeLength': '19',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,8808)'},
#   {'id': 'r759336',
#    'aid': '5341',
#    'readTimeLength': '97',
#    'agreeOrNot': '1',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,5341)'},
#   {'id': 'r759501',
#    'aid': '6810',
#    'readTimeLength': '3',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,6810)'},
#   {'id': 'r760794',
#    'aid': '2488',
#    'readTimeLength': '78',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,2488)'},
#   {'id': 'r770694',
#    'aid': '8137',
#    'readTimeLength': '20',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,8137)'},
#   {'id': 'r774772',
#    'aid': '840',
#    'readTimeLength': '96',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,840)'},
#   {'id': 'r780422',
#    'aid': '5360',
#    'readTimeLength': '52',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,5360)'},
#   {'id': 'r835707',
#    'aid': '3969',
#    'readTimeLength': '11',
#    'agreeOrNot': '1',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,3969)'},
#   {'id': 'r844197',
#    'aid': '9806',
#    'readTimeLength': '66',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,9806)'},
#   {'id': 'r848819',
#    'aid': '7825',
#    'readTimeLength': '83',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,7825)'},
#   {'id': 'r853796',
#    'aid': '4158',
#    'readTimeLength': '18',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,4158)'},
#   {'id': 'r861555',
#    'aid': '5861',
#    'readTimeLength': '69',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,5861)'},
#   {'id': 'r863432',
#    'aid': '7571',
#    'readTimeLength': '82',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,7571)'},
#   {'id': 'r873224',
#    'aid': '5498',
#    'readTimeLength': '53',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,5498)'},
#   {'id': 'r876282',
#    'aid': '5359',
#    'readTimeLength': '63',
#    'agreeOrNot': '1',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,5359)'},
#   {'id': 'r877437',
#    'aid': '3549',
#    'readTimeLength': '81',
#    'agreeOrNot': '1',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,3549)'},
#   {'id': 'r905779',
#    'aid': '3751',
#    'readTimeLength': '37',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,3751)'},
#   {'id': 'r919132',
#    'aid': '9786',
#    'readTimeLength': '75',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,9786)'},
#   {'id': 'r952785',
#    'aid': '2795',
#    'readTimeLength': '60',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,2795)'},
#   {'id': 'r958757',
#    'aid': '9',
#    'readTimeLength': '2',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,9)'},
#   {'id': 'r958959',
#    'aid': '9172',
#    'readTimeLength': '19',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '1',
#    'commentDetail': 'comments to this article: (1,9172)'},
#   {'id': 'r982083',
#    'aid': '6685',
#    'readTimeLength': '19',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,6685)'},
#   {'id': 'r987523',
#    'aid': '6914',
#    'readTimeLength': '98',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,6914)'},
#   {'id': 'r991734',
#    'aid': '2329',
#    'readTimeLength': '21',
#    'agreeOrNot': '0',
#    'commentOrNot': '1',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,2329)'},
#   {'id': 'r995201',
#    'aid': '7295',
#    'readTimeLength': '16',
#    'agreeOrNot': '0',
#    'commentOrNot': '0',
#    'shareOrNot': '0',
#    'commentDetail': 'comments to this article: (1,7295)'}]}

# %%
user_handler = UserTableHandler(db_handler)
json_file = "../db-generation/user.dat"
user_handler.bulk_insert(json_file)
# Out:
# Inserted 5000 records into User
# Inserted 5000 records into User
# Finished processing 10000 records.
# Execution time: 0:00:00.231713

# %%
len(user_handler.fetch_users({"region": "Beijing"}))
# Out:
# 100

# %%
article_handler = ArticleTableHandler(db_handler)
json_file = "../db-generation/article.dat"
article_handler.bulk_insert(json_file)
# Out:
# Inserted 5000 records into Article
# Inserted 5000 records into Article
# Inserted 4547 records into Article
# Finished processing 10000 records.
# Execution time: 0:00:00.254352

# %%
article_handler.fetch_articles({"aid": "1840"})
# Out:
# [{'_id': ObjectId('67582a685b433a7d9408c53d'),
#   'id': 'a1840',
#   'timestamp': '1506000001840',
#   'aid': '1840',
#   'title': 'title1840',
#   'category': 'technology',
#   'abstract': 'abstract of article 1840',
#   'articleTags': 'tags25',
#   'authors': 'author1651',
#   'language': 'zh',
#   'text': 'text_a1840.txt',
#   'image': 'image_a1840_0.jpg,image_a1840_1.jpg,image_a1840_2.jpg,',
#   'video': ''}]

# %%
read_handler = ReadTableHandler(db_handler)
read_handler.bulk_insert("../db-generation/read.dat")

# be_read_handler = BeReadTableHandler(db_handler)
# be_read_handler.bulk_insert("../db-generation/beRead.dat")
# Out:
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Inserted 5000 records into Read
# Finished processing 1000000 records.
# Execution time: 0:00:25.409458

# %%
read_handler.fetch_user_reads("1")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 read_handler.fetch_user_reads("1")
#
# AttributeError: 'ReadTableHandler' object has no attribute 'fetch_user_reads'

# %%
read_handler.fetch_reads_with_details()
# Out:
# [{'_id': ObjectId('67582a855b433a7d9408f371'),
#   'timestamp': '1506332297000',
#   'id': 'r0',
#   'uid': '8267',
#   'aid': '194',
#   'readTimeLength': '5',
#   'agreeOrNot': '0',
#   'commentOrNot': '1',
#   'shareOrNot': '0',
#   'commentDetail': 'comments to this article: (8267,194)',
#   'region': None,
#   'article_details': [],
#   'user_details': []},
#  {'_id': ObjectId('67582a855b433a7d9408f372'),
#   'timestamp': '1506332307000',
#   'id': 'r1',
#   'uid': '8166',
#   'aid': '2533',
#   'readTimeLength': '44',
#   'agreeOrNot': '0',
#   'commentOrNot': '0',
#   'shareOrNot': '0',
#   'commentDetail': 'comments to this article: (8166,2533)',
#   'region': None,
#   'article_details': [],
#   'user_details': []},
#  {'_id': ObjectId('67582a855b433a7d9408f373'),
#   'timestamp': '1506332317000',
#   'id': 'r2',
#   'uid': '8517',
#   'aid': '7739',
#   'readTimeLength': '36',
#   'agreeOrNot': '1',
#   'commentOrNot': '0',
#   'shareOrNot': '0',
#   'commentDetail': 'comments to this article: (8517,7739)',
#   'region': None,
#   'article_details': [],
#   'user_details': []},
#  {'_id': ObjectId('67582a855b433a7d9408f374'),
#   'timestamp': '1506332327000',
#   'id': 'r3',
#   'uid': '4422',
#   'aid': '5651',
#   'readTimeLength': '23',
#   'agreeOrNot': '0',
#   'commentOrNot': '0',
#   'shareOrNot': '1',
#   'commentDetail': 'comments to this article: (4422,5651)',
#   'region': None,
#   'article_details': [],
#   'user_details': []},
#  {'_id': ObjectId('67582a855b433a7d9408f375'),
#   'timestamp': '1506332337000',
#   'id': 'r4',
#   'uid': '9351',
#   'aid': '8728',
#   'readTimeLength': '94',
#   'agreeOrNot': '0',
#   'commentOrNot': '1',
#   'shareOrNot': '0',
#   'commentDetail': 'comments to this article: (9351,8728)',
#   'region': None,
#   'article_details': [],
#   'user_details': []},
#  {'_id': ObjectId('67582a855b433a7d9408f376'),
#   'timestamp': '1506332347000',
#   'id': 'r5',
#   'uid': '7160',
#   'aid': '8075',
#   'readTimeLength': '19',
#   'agreeOrNot': '0',
#   'commentOrNot': '0',
#   'shareOrNot': '1',
#   'commentDetail': 'comments to this article: (7160,8075)',
#   'region': None,
#   'article_details': [],
#   'user_details': []},
#  {'_id': ObjectId('67582a855b433a7d9408f377'),
#   'timestamp': '1506332357000',
#   'id': 'r6',
#   'uid': '4164',
#   'aid': '4532',
#   'readTimeLength': '34',
#   'agreeOrNot': '0',
#   'commentOrNot': '0',
#   'shareOrNot': '0',
#   'commentDetail': 'comments to this article: (4164,4532)',
#   'region': None,
#   'article_details': [],
#   'user_details': []},
#  {'_id': ObjectId('67582a855b433a7d9408f378'),
#   'timestamp': '1506332367000',
#   'id': 'r7',
#   'uid': '175',
#   'aid': '8780',
#   'readTimeLength': '68',
#   'agreeOrNot': '0',
#   'commentOrNot': '1',
#   'shareOrNot': '0',
#   'commentDetail': 'comments to this article: (175,8780)',
#   'region': None,
#   'article_details': [],
#   'user_details': []},
#  {'_id': ObjectId('67582a855b433a7d9408f379'),
#   'timestamp': '1506332377000',
#   'id': 'r8',
#   'uid': '171',
#   'aid': '4729',
#   'readTimeLength': '24',
#   'agreeOrNot': '0',
#   'commentOrNot': '0',
#   'shareOrNot': '0',
#   'commentDetail': 'comments to this article: (171,4729)',
#   'region': None,
#   'article_details': [],
#   'user_details': []},
#  {'_id': ObjectId('67582a855b433a7d9408f37a'),
#   'timestamp': '1506332387000',
#   'id': 'r9',
#   'uid': '9849',
#   'aid': '3692',
#   'readTimeLength': '11',
#   'agreeOrNot': '1',
#   'commentOrNot': '0',
#   'shareOrNot': '0',
#   'commentDetail': 'comments to this article: (9849,3692)',
#   'region': None,
#   'article_details': [],
#   'user_details': []}]
